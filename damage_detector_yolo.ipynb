# %% [markdown]
# **Yolov8 segmentation**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="bk3G8rrLiKUqECCCLgcZ")
project = rf.workspace("yomna-hupf9").project("car-jcznw")
dataset = project.version(2).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 823.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 4.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=segment mode=train model=yolov8n-seg data='/content/car-2/data.yaml' epochs=70 imgsz=640 plots=True  project="/content/drive/MyDrive/damaged_car/car/working", name= "working"
# Out:
# WARNING ⚠️ 'project=/content/drive/MyDrive/damaged_car/car/working,' does not require trailing comma ',', updating to 'project=/content/drive/MyDrive/damaged_car/car/working'.
# Ultralytics YOLOv8.0.230 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model=YOLO('/content/drive/MyDrive/damaged_car/car/working/working2/weights/best.pt')

# %%
metrics=model.val()
# Out:
# Ultralytics YOLOv8.0.230 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3259234 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /content/car-2/valid/labels.cache... 745 images, 0 backgrounds, 0 corrupt: 100%|██████████| 745/745 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 47/47 [00:17<00:00,  2.63it/s]
#                    all        745       1609      0.731      0.705      0.717      0.557      0.734      0.703      0.715      0.542
#                  crack        745        168      0.424      0.328      0.265      0.127       0.44      0.339      0.276     0.0977
#                   dent        745        475      0.648      0.531      0.586      0.338      0.655      0.528      0.578      0.296
# ...

# %%
# !yolo task=segment mode=predict model='/content/drive/MyDrive/damaged_car/car/working/working2/weights/best.pt' conf=0.25 source='/content/car-2/test/images' save=True
# Out:
# Ultralytics YOLOv8.0.230 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3259234 parameters, 0 gradients, 12.0 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/370 /content/car-2/test/images/000025_jpg.rf.8b458f785afcb8664d49cc48a0e5379b.jpg: 640x640 1 lamp broken, 1 scratch, 22.3ms
# image 2/370 /content/car-2/test/images/000037_jpg.rf.40fb3b58ec3baa120cc5cf1bb9f3e259.jpg: 640x640 3 scratchs, 1 tire flat, 10.3ms
# image 3/370 /content/car-2/test/images/000038_jpg.rf.dbd7c45620edcfe54e0c9e3ffb8d4aaa.jpg: 640x640 3 dents, 1 lamp broken, 10.3ms
# image 4/370 /content/car-2/test/images/000050_jpg.rf.39ef87b463e4874b9678a7eb90d3cb00.jpg: 640x640 1 scratch, 9.9ms
# image 5/370 /content/car-2/test/images/000066_jpg.rf.84a387ffaaf3dc20d20426e88115b6b0.jpg: 640x640 1 scratch, 10.0ms
# image 6/370 /content/car-2/test/images/000089_jpg.rf.c33ea882cbd69a0e248be7ed18d76186.jpg: 640x640 1 crack, 1 dent, 9.9ms
# ...

# %%
results = model.predict(source='/content/car-2/test/images/000025_jpg.rf.8b458f785afcb8664d49cc48a0e5379b.jpg', conf=0.25)
# Out:
# image 1/1 /content/car-2/test/images/000025_jpg.rf.8b458f785afcb8664d49cc48a0e5379b.jpg: 640x640 1 lamp broken, 1 scratch, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 30.8ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# **Detectron2**
